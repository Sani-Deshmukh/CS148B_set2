# %%
import os
import sys

print("cwd:", os.getcwd())
print("sys.path[0]:", sys.path[0])
# !pwd
# !ls
# !find . -maxdepth 2 -type d | sort | head -50
# Out:
# cwd: /content
# sys.path[0]: /content
# /content
# sample_data
# .
# ./.config
# ./.config/configurations
# ./.config/logs
# ./sample_data

# %%
# !python3 -m systems.benchmark --model-size small --context-length 128 --warmup-steps 5 --measure-steps 10 --mode forward
# Out:
# /usr/bin/python3: Error while finding module specification for 'systems.benchmark' (ModuleNotFoundError: No module named 'systems')
